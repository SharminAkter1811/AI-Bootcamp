# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    "Student":["Asha","Robi","Rana","Piyash","Kajol","Tithi","Nila","Abir","Siyam","Rafi"],
    "Study_Hours":[6,9,2,5,4,5,7,1,9,10],
    "Sleep_Hours":[6,5,9,7,7,6,5,8,7,6],
    "Scores":[70,90,60,75,65,78,85,40,95,89]
}
df=pd.DataFrame(data)
df
# Out:
#   Student  Study_Hours  Sleep_Hours  Scores
# 0    Asha            6            6      70
# 1    Robi            9            5      90
# 2    Rana            2            9      60
# 3  Piyash            5            7      75
# 4   Kajol            4            7      65
# 5   Tithi            5            6      78
# 6    Nila            7            5      85
# 7    Abir            1            8      40
# 8   Siyam            9            7      95
# 9    Rafi           10            6      89

# %%
df["Scores"].mean()
# Out:
# np.float64(74.7)

# %%
df["Scores"].max()
# Out:
# np.int64(95)

# %%
df[df["Study_Hours"]>5]
# Out:
#   Student  Study_Hours  Sleep_Hours  Scores
# 0    Asha            6            6      70
# 1    Robi            9            5      90
# 6    Nila            7            5      85
# 8   Siyam            9            7      95
# 9    Rafi           10            6      89

# %%
df["Study_Hours"].mean()
# Out:
# np.float64(5.8)

# %%
plt.scatter(df["Sleep_Hours"], df["Scores"])
plt.xlabel("Study_Hours")
plt.ylabel("Scores")
plt.title("Study_Hours vs Scores")
plt.show()

# %%
plt.scatter(df["Sleep_Hours"],df["Scores"])
plt.xlabel("Sleep_Hours")
plt.ylabel("Scores")
plt.title("Sleep_Hours vs Scores")
plt.show()
